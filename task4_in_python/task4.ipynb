# %% [markdown]
# # Halloween candy dirty data

# %%
import pandas as pd

# %%
df_15 = pd.read_csv('raw_data/candy_ranking_data/candy-2015.csv')
df_16 = pd.read_csv('raw_data/candy_ranking_data/candy-2016.csv')
df_17 = pd.read_csv('raw_data/candy_ranking_data/candy-2017.csv')

# %% [markdown]
# I will work on each of them then join them together

# %%
df_15.head()
# Out:
#             Timestamp How old are you?  \
# 0  10/23/2015 8:46:20               35
# 1  10/23/2015 8:46:51               41
# 2  10/23/2015 8:47:34               33
# 3  10/23/2015 8:47:58               31
# 4  10/23/2015 8:48:11               30
#
#   Are you going actually going trick or treating yourself?  [Butterfinger]  \
# 0                                                 No                   JOY
# 1                                                 No                   JOY
# 2                                                 No               DESPAIR
# 3                                                 No                   JOY
# 4                                                 No                   NaN
#
#    [100 Grand Bar]  \
# 0              NaN
# 1              JOY
# 2          DESPAIR
# 3              JOY
# 4              JOY
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                            DESPAIR
# 2                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#    [Any full-sized candy bar]  [Black Jacks]  [Bonkers]  [Bottle Caps]  ...  \
# 0                         JOY            NaN        NaN            NaN  ...
# 1                         JOY        DESPAIR    DESPAIR            JOY  ...
# 2                         JOY        DESPAIR    DESPAIR        DESPAIR  ...
# 3                         JOY        DESPAIR    DESPAIR            JOY  ...
# 4                         JOY            NaN        NaN            NaN  ...
#
#    [Necco Wafers] Which day do you prefer, Friday or Sunday?  \
# 0             NaN                                        NaN
# 1         DESPAIR                                        NaN
# 2         DESPAIR                                        NaN
# 3         DESPAIR                                        NaN
# 4             NaN                                        NaN
#
#   Please estimate the degrees of separation you have from the following folks [Bruce Lee]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [JK Rowling]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [Malala Yousafzai]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [Thom Yorke]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [JJ Abrams]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [Hillary Clinton]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [Donald Trump]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please estimate the degrees of separation you have from the following folks [Beyoncé Knowles]
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 124 columns]

# %%
col_list = []
for col in df_15.columns:
    if col.startswith(' [') == True:
        col_list.append(col)
col_list
col_list.append("How old are you?")
col_list.append("Are you going actually going trick or treating yourself?")

# %%
sweet_15 = df_15[col_list].melt(var_name="sweet")

# %%
short_15 = df_15[col_list].rename(columns={"How old are you?": "age", "Are you going actually going trick or treating yourself?": "going_out"})

# %%
short_15.melt(id_vars=["age", "going_out"],var_name="sweet")
# Out:
#        age going_out            sweet    value
# 0       35        No   [Butterfinger]      JOY
# 1       41        No   [Butterfinger]      JOY
# 2       33        No   [Butterfinger]  DESPAIR
# 3       31        No   [Butterfinger]      JOY
# 4       30        No   [Butterfinger]      NaN
# ...     ..       ...              ...      ...
# 534845  50        No   [Necco Wafers]  DESPAIR
# 534846  43        No   [Necco Wafers]  DESPAIR
# 534847  35       Yes   [Necco Wafers]      NaN
# 534848  38        No   [Necco Wafers]      JOY
# 534849  44        No   [Necco Wafers]      JOY
#
# [534850 rows x 4 columns]
